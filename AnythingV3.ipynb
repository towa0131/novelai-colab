# %% [markdown]
# コードを実行する前に，Google Drive のルートに `AnythingV3` フォルダを作成しておく．
#
# また，上の「ランタイム」から「ランタイムのタイプを変更」→「ハードウェア アクセラレータ」を `GPU` に変更する．

# %%
from google.colab import drive

drive.mount("/content/drive")

# %%
# !git clone https://github.com/camenduru/stable-diffusion-webui
# %cd /content/stable-diffusion-webui

# %% [markdown]
# 以下は AnythingV3 のモデルをダウンロードするためのコードなので，実行は初回のみでよい．
#
# === ここから ===

# %%
# !wget https://huggingface.co/Linaqruf/anything-v3.0/resolve/main/Anything-V3.0-pruned.ckpt -O /content/drive/MyDrive/AnythingV3/Anything-V3.0-pruned.ckpt
# !wget https://huggingface.co/Linaqruf/anything-v3.0/resolve/main/Anything-V3.0.vae.pt -O /content/drive/MyDrive/AnythingV3/Anything-V3.0-pruned.vae.pt

# %% [markdown]
# === ここまで ===

# %%
# !cp /content/drive/MyDrive/AnythingV3/Anything-V3.0-pruned.ckpt /content/stable-diffusion-webui/models/Stable-diffusion/
# !cp /content/drive/MyDrive/AnythingV3/Anything-V3.0-pruned.vae.pt /content/stable-diffusion-webui/models/Stable-diffusion/

# %% [markdown]
# 以下を実行すると，サーバが起動する．表示された public URL にアクセスし，ユーザ名 : `user`，パスワード : `user` でログインする．

# %%
# !COMMANDLINE_ARGS="--share --gradio-debug --gradio-auth user:user" REQS_FILE="requirements.txt" python launch.py
